# %%
# %cd ~/sd212/Gaslight_Gatekeep_Girlboss
# Out:
# /home/mids/m286744/sd212/Gaslight_Gatekeep_Girlboss

# %%
import pandas as pd
from concurrent.futures import ProcessPoolExecutor
import re

# %%
bigfile = pd.read_csv('contracts.csv')
defense= bigfile[bigfile['parent_award_agency_name'] == 'DEPT OF DEFENSE']
defense['recipient_name'].value_counts()
# Out:
# /tmp/ipykernel_1722327/415463095.py:1: DtypeWarning: Columns (47,71,72,81,115,135,136,164,165) have mixed types. Specify dtype option on import or set low_memory=False.
#   bigfile = pd.read_csv('contracts.csv')
# recipient_name
# AMERISOURCEBERGEN DRUG CORP               10710
# CARDINAL HEALTH 200, LLC                   6163
# ASRC FEDERAL FACILITIES LOGISTICS, LLC     5554
# OWENS & MINOR DISTRIBUTION INC             2838
# NOBLE SUPPLY & LOGISTICS, LLC              2279
#                                           ...
# NOBLES WORLDWIDE, INC.                        1
# SCIOTEQ                                       1
# SERKA TAAHHUT INSAAT ANONIM SIRKETI           1
# VINSON PROCESS CONTROLS COMPANY, L.P.         1
# JMZ ARCHITECTS & PLANNERS, PC                 1
# Name: count, Length: 3489, dtype: int64
